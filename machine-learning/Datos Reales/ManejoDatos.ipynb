# %% [markdown]
# # Manejo de datos

# %% [markdown]
# ## Observar data

# %% [markdown]
# Observar los datos que tengo para ver cual puede ser útil

# %%
import os
import pandas as pd

# Define the folder path
folder_path = 'CSV Completo'

# Iterate through all files in the folder
for filename in os.listdir(folder_path):
    #print(filename)
    if filename.endswith('.CSV'):
        file_path = os.path.join(folder_path, filename)
        # Read the first line of the CSV file
        with open(file_path, 'r') as file:
            first_line = file.readline().strip()
        # Print the filename and the first line
        print(f'Archivo: {filename}')
        print(f'{first_line}')
        print('-----------------------------')

folder_path1 = 'CSV Sin Columna'

# Iterate through all files in the folder
for filename in os.listdir(folder_path1):
    #print(filename)
    if filename.endswith('.CSV'):
        file_path = os.path.join(folder_path1, filename)
        # Read the first line of the CSV file
        with open(file_path, 'r') as file:
            first_line = file.readline().strip()
        # Print the filename and the first line
        print(f'Archivo: {filename}')
        print(f'{first_line}')
        print('-----------------------------')
# Out:
# Archivo: FILE1123.CSV
# $Date,$Time,DeltaTPid.Pid_SP,Pc_OIT_24Real[001]
# -----------------------------
# Archivo: FILE1A2.CSV
# $Date;$Time;Pc_OIT_24Real[000];Pc_OIT_24Real[004];DeltaTPid.Pid_SP
# -----------------------------
# Archivo: FILE1A3.CSV
# $Date;$Time;Pc_OIT_24Real[000];Pc_OIT_24Real[004];DeltaTPid.Pid_SP;Pc_OIT_24Real[001]
# -----------------------------
# Archivo: FILE1JULIO.CSV
# $Date,$Time,Pc_OIT_24Real[000],Pc_OIT_24Real[004],DeltaTPid.Pid_SP,Pc_OIT_24Real[001]Pid.Pid_SP,Pc_OIT_24Real[001],FT1501.Value
# -----------------------------
# Archivo: FILE1NIVELACEITE.CSV
# $Date,$Time,Pc_OIT_24Real[001]Pid.Pid_SP,Pc_OIT_24Real[001]
# -----------------------------
# Archivo: FILEJULIO.CSV
# $Date,$Time,Pc_OIT_24Real[000],Pc_OIT_24Real[004],DeltaTPid.Pid_SP,Pc_OIT_24Real[001]Pid.Pid_SP,Pc_OIT_24Real[001],FT1501.Value
# -----------------------------
# Archivo: FILEJUNIO.CSV
# $Date,$Time,Pc_OIT_24Real[000],Pc_OIT_24Real[004],DeltaTPid.Pid_SP,Pc_OIT_24Real[001]Pid.Pid_SP,Pc_OIT_24Real[001],FT1501.Value
# -----------------------------
# Archivo: HUMEDADJULIO.CSV
# $Date,$Time,Pc_OIT_24Real[000]
# -----------------------------
# Archivo: HUMEDADJUNIO.CSV
# $Date,$Time,Pc_OIT_24Real[000]
# -----------------------------
# Archivo: FILE11A_MODIFICADO.CSV
# $Date,$Time,DeltaTPid.Pid_SP
# -----------------------------
# Archivo: FILE1A1_MODIFICADO.CSV
# $Date,$Time,DeltaTPid.Pid_SP
# -----------------------------
# Archivo: FILE1AA_MODIFICADO.CSV
# $Date,$Time,Pc_OIT_24Real[000],Pc_OIT_24Real[004],DeltaTPid.Pid_SP,LT1301.Value,FT1501.Value,TT1501.Value
# -----------------------------
# Archivo: FILE1DELTAT_MODIFICADO.CSV
# $Date,$Time,DeltaTPid.Pid_SP
# -----------------------------
# Archivo: FILE1FLUJOACEITE_MODIFICADO.CSV
# $Date,$Time,FT1501.Value
# -----------------------------
# Archivo: FILE1HUMEDADFILTRADA_MODIFICADO.CSV
# $Date,$Time,Pc_OIT_24Real[000]
# -----------------------------
# Archivo: FILE1HUMEDAD_MODIFICADO.CSV
# $Date,$Time,Pc_OIT_24Real[000]
# -----------------------------
# Archivo: FILE1VELMAESTRA_MODIFICADO.CSV
# $Date,$Time,Pc_OIT_24Real[000],DeltaTPid.Pid_SP
# -----------------------------

# %% [markdown]
# - FILE1AA_MODIFICADO: humedad, master speed, nivel banda tolva, flujo aceite, temp salida intercambiador, deltaTpid
# - FILEJUNIO:          humedad, master speed, nivel aceite actual PID, nivel aceite actual, flujo aceite. deltaTpid
# - FILEJULIO:          same filejunio
# - FILE1JULIO:         same filejunio
# - FILE1A3:            humedad, master spped, nivel aceite actual, deltaTPID

# %% [markdown]
# ## Quitar columna de BDD

# %%
import pandas as pd

# Leer el archivo CSV usando las variables definidas
df = pd.read_csv('CSV/FILE1A1.CSV', usecols=[0, 1, 2])

# Guardar el archivo modificado en otra carpeta con otro nombre
nuevo_archivo = 'CSV Sin Columna' + '/FILE1A1_MODIFICADO.CSV'
df.to_csv(nuevo_archivo, index=False)

# %%
# Leer el archivo CSV usando las variables definidas
df = pd.read_csv('CSV/FILE1AA.CSV', usecols=[0, 1, 2,3,4,5,6,7])

# Guardar el archivo modificado en otra carpeta con otro nombre
nuevo_archivo = 'CSV Sin Columna' + '/FILE1AA_MODIFICADO.CSV'
df.to_csv(nuevo_archivo, index=False)

# %%
# Leer el archivo CSV usando las variables definidas
df = pd.read_csv('CSV/FILE1DELTAT.CSV', usecols=[0, 1, 2])

# Guardar el archivo modificado en otra carpeta con otro nombre
nuevo_archivo = 'CSV Sin Columna' + '/FILEDELTAT_MODIFICADO.CSV'
df.to_csv(nuevo_archivo, index=False)

# %%
# Leer el archivo CSV usando las variables definidas
df = pd.read_csv('CSV/FILE1HUMEDAD.CSV', usecols=[0, 1, 2])

# Guardar el archivo modificado en otra carpeta con otro nombre
nuevo_archivo = 'CSV Sin Columna' + '/FILE1HUMEDAD_MODIFICADO.CSV'
df.to_csv(nuevo_archivo, index=False)

# %%
# Leer el archivo CSV usando las variables definidas
df = pd.read_csv('CSV/FILE1HUMEDADFILTRADA.CSV', usecols=[0, 1, 2])

# Guardar el archivo modificado en otra carpeta con otro nombre
nuevo_archivo = 'CSV Sin Columna' + '/FILE1HUMEDADFILTRADA_MODIFICADO.CSV'
df.to_csv(nuevo_archivo, index=False)

# %%
# Leer el archivo CSV usando las variables definidas
df = pd.read_csv('CSV/FILE1VELMAESTRA.CSV', usecols=[0, 1, 2,3])

# Guardar el archivo modificado en otra carpeta con otro nombre
nuevo_archivo = 'CSV Sin Columna' + '/FILE1VELMAESTRA_MODIFICADO.CSV'
df.to_csv(nuevo_archivo, index=False)

# %%
# Leer el archivo CSV usando las variables definidas
df = pd.read_csv('CSV/FILE11A.CSV', usecols=[0, 1, 2])

# Guardar el archivo modificado en otra carpeta con otro nombre
nuevo_archivo = 'CSV Sin Columna' + '/FILE11A_MODIFICADO.CSV'
df.to_csv(nuevo_archivo, index=False)
